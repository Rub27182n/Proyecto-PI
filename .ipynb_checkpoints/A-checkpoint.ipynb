# %% [markdown]
# ___
# <img style="float: right; margin: 0px 0px 15px 15px;" src="https://upload.wikimedia.org/wikipedia/commons/0/08/Pareto_Efficient_Frontier_for_the_Markowitz_Portfolio_selection_problem..png" width="300px" height="100px" />
#
#
# # Proyecto Final
#
# En el proyecto final diseñarás un portafolio de inversión utilizando activos (o ETFs) reales de tu preferencia. Utilizarás todas las herramientas vistas a lo largo del curso para este fin, y después, evaluarás qué tan buena hubiera sido tu inversión de haber invertido en este portafolio.
#
# El proyecto se realizará en equipos de mínimo dos (2) y máximo tres (3) personas. Ni más, ni menos. Para esto, deberán conformar los equipos en este momento, y designar a un miembro del equipo que me envíe un correo con los nombres de los integrantes.
# ___

# %% [markdown]
# ## 1. Elección de activos
#
# Lo primero es elegir los activos que van a utilizar. En este punto tienen tres opciones:
#
# 1. Si deciden trabajar únicamente con acciones de empresas particulares, deben elegir y listar mínimo 20 activos.
#
# 2. Si deciden trabajar únicamente con ETFs, deben elegir y listar mínimo 10 ETFs.
#
# 3. Si deciden trabajar con una combinación de acciones y ETFs, deben elegir y listar por lo menos 5 ETFs y 10 activos.
#
# En cualquiera de los tres casos deben explicar detalladamente la elección de cada uno de los activos y/o ETFs que elijan.

# %% [markdown]
# Nuestra elección fue la opción 3 y para esto se escogieron los siguientes instrumentos:
#
# * ETFs:
#
#     * ARKK:
#
#     * QYLD:
#
#     * SPY: Lo elegimos por que el S&P 500 es de los principales índices de mercado y lo conforman empresas de gran renombre como apple, microsoft, Johnson & Johnson, entre otras.
#
#     * VTI: Abarca los principales sectores de materias primas, finanzas, salud, tecnología, petróleo, entre otros.
#
#     * VYM: Porque está compuesto de empresas que ofrecen dividendos sustanciales (397 grandes y medianas empresas).
#
# * Activos:
#
#     * IBM:
#
#     * American airlines:
#
#     * Paypal:
#
#     * Pfizer:
#
#     * Twitter:
#
#     * Apple:
#
#     * Tesla:
#
#     * Netflix:
#
#     * Amazon:
#
#     * Coca-Cola:
#
#     * Tasa libre de riesgo (cetes):

# %% [markdown]
# ## 2. Selección de portafolios
#
# Una vez elegidos los activos y/o ETFs:
#
# 1. Usando los precios históricos de dichos activos hasta el 2015-12-31 (la fecha inicial es un parámetro que ustedes deberán elegir), diseñarán un portafolio en el que (hipotéticamente) habrían invertido durante todo el 2016. Para esto, deberán suponer un coeficiente de aversión al riesgo.
#
# 2. Usando los precios históricos de dichos activos hasta el 2016-12-31, diseñarán un portafolio en el que (hipotéticamente) habrían invertido durante todo el 2017.
#
# 3. Usando los precios históricos de dichos activos hasta el 2017-12-31, diseñarán un portafolio en el que (hipotéticamente) habrían invertido durante todo el 2018.
#
# 4. Usando los precios históricos de dichos activos hasta el 2018-12-31, diseñarán un portafolio en el que (hipotéticamente) habrían invertido durante todo el 2019.
#
# 5. Usando los precios históricos de dichos activos hasta el 2019-12-31, diseñarán un portafolio en el que (hipotéticamente) habrían invertido durante todo el 2020.
#
# 6. Usando los precios históricos de dichos activos hasta el 2020-12-31, diseñarán un portafolio en el que (hipotéticamente) habrían invertido durante todo el 2021.

# %%
import matplotlib
import numpy as np
import pandas as pd
import scipy.stats as stats
import plotly.graph_objs as go
import matplotlib.pyplot as plt
import pandas_datareader.data as web
from plotly.subplots import make_subplots
import scipy.optimize as opt
from scipy.optimize import minimize

# %%
# Función para descargar precios de cierre ajustados:
def get_adj_closes(tickers, start_date=None, end_date=None, freq = None):
    closes = web.YahooDailyReader(symbols=tickers, start=start_date, end=end_date, interval = freq).read()['Adj Close']
    return closes

# %%
# Función objetivo
def varianza(w,Sigma):
    return w.T.dot(Sigma).dot(w)

# %%
# Función objetivo
def menos_RS(w,Eind,Sigma,rf):
    Ep=Eind.T.dot(w)
    sp=(w.T.dot(Sigma).dot(w))**.5
    RS=(Ep-rf)/sp
    return -RS

# %%
tickers = 'VNQ VBK SPY VTI VYM IBM AAL GOOG PFE SONY AAPL VWAGY NFLX AMZN KO'
tickers = tickers.split(' ')
tickers
# Out:
# ['VNQ',
#  'VBK',
#  'SPY',
#  'VTI',
#  'VYM',
#  'IBM',
#  'AAL',
#  'GOOG',
#  'PFE',
#  'SONY',
#  'AAPL',
#  'VWAGY',
#  'NFLX',
#  'AMZN',
#  'KO']

# %%
# Vector de w
N=101
w=np.linspace(0,1,N)

# %%
g=8

# %% [markdown]
# # 2.1

# %%
start = '2010-01-01'
end = '2015-12-31'
prices=get_adj_closes(tickers, start, end, 'd')
prices.head()
# Out:
# Symbols           VNQ        VBK        SPY        VTI        VYM        IBM  \
# Date
# 2010-01-04  28.493959  56.132561  90.790062  46.223129  27.170769  92.528694
# 2010-01-05  28.461987  56.416996  91.030411  46.400578  27.170769  91.410950
# 2010-01-06  28.410826  56.582134  91.094490  46.465103  27.227226  90.817116
# 2010-01-07  28.717825  56.756470  91.479050  46.658669  27.276627  90.502762
# 2010-01-08  28.506762  57.086765  91.783432  46.811913  27.326035  91.410950
#
# Symbols          AAL        GOOG        PFE       SONY      AAPL      VWAGY  \
# Date
# 2010-01-04  4.496876  312.204773  11.810514  30.020000  6.583586  10.407018
# 2010-01-05  5.005957  310.829926  11.642064  29.879999  6.594968  10.479625
# 2010-01-06  4.798555  302.994293  11.604629  29.850000  6.490066  10.407018
# 2010-01-07  4.939965  295.940735  11.560955  29.799999  6.478067  10.649042
# 2010-01-08  4.845690  299.885956  11.654539  30.410000  6.521136  10.866863
#
# Symbols         NFLX        AMZN         KO
# Date
# 2010-01-04  7.640000  133.899994  20.098238
# 2010-01-05  7.358571  134.690002  19.855110
# 2010-01-06  7.617143  132.250000  19.848063
# 2010-01-07  7.485714  130.000000  19.798731
# 2010-01-08  7.614286  133.520004  19.432291

# %%
prices.plot(figsize=(6,4),grid=True)
plt.ylabel('Precios')
plt.legend(loc='upper left',bbox_to_anchor=(1.3,1))

# %%
ret = prices.pct_change().dropna()
ret.head()
# Out:
# Symbols          VNQ       VBK       SPY       VTI       VYM       IBM  \
# Date
# 2010-01-05 -0.001122  0.005067  0.002647  0.003839  0.000000 -0.012080
# 2010-01-06 -0.001798  0.002927  0.000704  0.001391  0.002078 -0.006496
# 2010-01-07  0.010806  0.003081  0.004222  0.004166  0.001814 -0.003461
# 2010-01-08 -0.007350  0.005820  0.003327  0.003284  0.001811  0.010035
# 2010-01-11  0.005833 -0.002089  0.001397  0.001378  0.004907 -0.010470
#
# Symbols          AAL      GOOG       PFE      SONY      AAPL     VWAGY  \
# Date
# 2010-01-05  0.113208 -0.004404 -0.014263 -0.004664  0.001729  0.006977
# 2010-01-06 -0.041431 -0.025209 -0.003216 -0.001004 -0.015906 -0.006928
# 2010-01-07  0.029469 -0.023280 -0.003763 -0.001675 -0.001849  0.023256
# 2010-01-08 -0.019084  0.013331  0.008095  0.020470  0.006648  0.020455
# 2010-01-11 -0.019455 -0.001512  0.008030  0.006248 -0.008821 -0.002227
#
# Symbols         NFLX      AMZN        KO
# Date
# 2010-01-05 -0.036836  0.005900 -0.012097
# 2010-01-06  0.035139 -0.018116 -0.000355
# 2010-01-07 -0.017254 -0.017013 -0.002485
# 2010-01-08  0.017176  0.027077 -0.018508
# 2010-01-11 -0.001313 -0.024041  0.020308

# %%
ret.plot(figsize=(6,4),grid=True)
plt.ylabel('Rendimientos porcentuales')
plt.legend(loc='upper left',bbox_to_anchor=(1.3,1))

# %%
#Rendimientos y volatilidades esperadas
summary = pd.DataFrame(data={'Media': 252*ret.mean(),
                            'Vol':((252)**(.5))*ret.std()})
summary
# Out:
#             Media       Vol
# Symbols
# VNQ      0.155493  0.199559
# VBK      0.143562  0.205940
# SPY      0.130934  0.157928
# VTI      0.132863  0.162344
# VYM      0.132139  0.139865
# IBM      0.045872  0.190062
# AAL      0.493348  0.504898
# GOOG     0.181028  0.257254
# PFE      0.143711  0.187987
# SONY     0.025782  0.343752
# AAPL     0.254032  0.266587
# VWAGY    0.123264  0.351877
# NFLX     0.625627  0.591866
# AMZN     0.324013  0.328069
# KO       0.109726  0.152303

# %%
#Matriz de varianza - covarianza
cov_ret = ret.cov()
cov_ret
# Out:
# Symbols       VNQ       VBK       SPY       VTI       VYM       IBM       AAL  \
# Symbols
# VNQ      0.000158  0.000127  0.000099  0.000103  0.000086  0.000073  0.000162
# VBK      0.000127  0.000168  0.000120  0.000126  0.000101  0.000093  0.000187
# SPY      0.000099  0.000120  0.000099  0.000101  0.000086  0.000080  0.000140
# VTI      0.000103  0.000126  0.000101  0.000105  0.000088  0.000081  0.000147
# VYM      0.000086  0.000101  0.000086  0.000088  0.000078  0.000070  0.000117
# IBM      0.000073  0.000093  0.000080  0.000081  0.000070  0.000143  0.000094
# AAL      0.000162  0.000187  0.000140  0.000147  0.000117  0.000094  0.001012
# GOOG     0.000087  0.000118  0.000097  0.000099  0.000079  0.000080  0.000125
# PFE      0.000080  0.000091  0.000080  0.000081  0.000072  0.000062  0.000108
# SONY     0.000110  0.000134  0.000111  0.000113  0.000096  0.000093  0.000158
# AAPL     0.000082  0.000112  0.000093  0.000095  0.000075  0.000080  0.000134
# VWAGY    0.000133  0.000166  0.000131  0.000136  0.000112  0.000112  0.000171
# NFLX     0.000091  0.000148  0.000100  0.000107  0.000079  0.000071  0.000192
# AMZN     0.000103  0.000142  0.000110  0.000113  0.000088  0.000090  0.000166
# KO       0.000061  0.000064  0.000060  0.000060  0.000057  0.000054  0.000078
#
# Symbols      GOOG       PFE      SONY      AAPL     VWAGY      NFLX      AMZN  \
# Symbols
# VNQ      0.000087  0.000080  0.000110  0.000082  0.000133  0.000091  0.000103
# VBK      0.000118  0.000091  0.000134  0.000112  0.000166  0.000148  0.000142
# SPY      0.000097  0.000080  0.000111  0.000093  0.000131  0.000100  0.000110
# VTI      0.000099  0.000081  0.000113  0.000095  0.000136  0.000107  0.000113
# VYM      0.000079  0.000072  0.000096  0.000075  0.000112  0.000079  0.000088
# IBM      0.000080  0.000062  0.000093  0.000080  0.000112  0.000071  0.000090
# AAL      0.000125  0.000108  0.000158  0.000134  0.000171  0.000192  0.000166
# GOOG     0.000263  0.000075  0.000099  0.000110  0.000122  0.000142  0.000169
# PFE      0.000075  0.000140  0.000086  0.000065  0.000097  0.000065  0.000081
# SONY     0.000099  0.000086  0.000469  0.000098  0.000152  0.000114  0.000121
# AAPL     0.000110  0.000065  0.000098  0.000282  0.000119  0.000084  0.000113
# VWAGY    0.000122  0.000097  0.000152  0.000119  0.000491  0.000124  0.000140
# NFLX     0.000142  0.000065  0.000114  0.000084  0.000124  0.001390  0.000254
# AMZN     0.000169  0.000081  0.000121  0.000113  0.000140  0.000254  0.000427
# KO       0.000052  0.000053  0.000072  0.000049  0.000077  0.000040  0.000057
#
# Symbols        KO
# Symbols
# VNQ      0.000061
# VBK      0.000064
# SPY      0.000060
# VTI      0.000060
# VYM      0.000057
# IBM      0.000054
# AAL      0.000078
# GOOG     0.000052
# PFE      0.000053
# SONY     0.000072
# AAPL     0.000049
# VWAGY    0.000077
# NFLX     0.000040
# AMZN     0.000057
# KO       0.000092

# %%
#Matriz de correlación
corr = ret.corr()
corr
# Out:
# Symbols       VNQ       VBK       SPY       VTI       VYM       IBM       AAL  \
# Symbols
# VNQ      1.000000  0.778109  0.791872  0.799431  0.779052  0.482922  0.404145
# VBK      0.778109  1.000000  0.926585  0.948556  0.882445  0.596450  0.452825
# SPY      0.791872  0.926585  1.000000  0.996311  0.979941  0.674202  0.443564
# VTI      0.799431  0.948556  0.996311  1.000000  0.972344  0.664369  0.453307
# VYM      0.779052  0.882445  0.979941  0.972344  1.000000  0.667618  0.417179
# IBM      0.482922  0.596450  0.674202  0.664369  0.667618  1.000000  0.247377
# AAL      0.404145  0.452825  0.443564  0.453307  0.417179  0.247377  1.000000
# GOOG     0.428912  0.562838  0.599821  0.599191  0.554001  0.413369  0.242521
# PFE      0.540590  0.590157  0.678917  0.669993  0.691994  0.436361  0.286755
# SONY     0.403005  0.478384  0.513049  0.511185  0.501134  0.358437  0.228725
# AAPL     0.388612  0.515423  0.556020  0.554982  0.509430  0.397793  0.250406
# VWAGY    0.477462  0.578831  0.595093  0.598809  0.575308  0.423710  0.242745
# NFLX     0.194951  0.305730  0.269639  0.280455  0.240603  0.158411  0.161887
# AMZN     0.396888  0.530096  0.533342  0.535056  0.483962  0.364241  0.253212
# KO       0.503204  0.515347  0.631338  0.615504  0.675461  0.468825  0.254612
#
# Symbols      GOOG       PFE      SONY      AAPL     VWAGY      NFLX      AMZN  \
# Symbols
# VNQ      0.428912  0.540590  0.403005  0.388612  0.477462  0.194951  0.396888
# VBK      0.562838  0.590157  0.478384  0.515423  0.578831  0.305730  0.530096
# SPY      0.599821  0.678917  0.513049  0.556020  0.595093  0.269639  0.533342
# VTI      0.599191  0.669993  0.511185  0.554982  0.598809  0.280455  0.535056
# VYM      0.554001  0.691994  0.501134  0.509430  0.575308  0.240603  0.483962
# IBM      0.413369  0.436361  0.358437  0.397793  0.423710  0.158411  0.364241
# AAL      0.242521  0.286755  0.228725  0.250406  0.242745  0.161887  0.253212
# GOOG     1.000000  0.388877  0.283265  0.405144  0.339781  0.234445  0.504737
# PFE      0.388877  1.000000  0.337006  0.327737  0.369426  0.146821  0.331670
# SONY     0.283265  0.337006  1.000000  0.269780  0.317123  0.141761  0.269812
# AAPL     0.405144  0.327737  0.269780  1.000000  0.318661  0.133987  0.324770
# VWAGY    0.339781  0.369426  0.317123  0.318661  1.000000  0.150521  0.304966
# NFLX     0.234445  0.146821  0.141761  0.133987  0.150521  1.000000  0.329571
# AMZN     0.504737  0.331670  0.269812  0.324770  0.304966  0.329571  1.000000
# KO       0.337309  0.463056  0.346346  0.301148  0.362442  0.110744  0.286690
#
# Symbols        KO
# Symbols
# VNQ      0.503204
# VBK      0.515347
# SPY      0.631338
# VTI      0.615504
# VYM      0.675461
# IBM      0.468825
# AAL      0.254612
# GOOG     0.337309
# PFE      0.463056
# SONY     0.346346
# AAPL     0.301148
# VWAGY    0.362442
# NFLX     0.110744
# AMZN     0.286690
# KO       1.000000

# %%
S=np.diag(summary['Vol'].values)
Sigma = S.dot(corr).dot(S)
Eind=summary['Media'].values

# %%
# Número de activos
n=len(Eind)
# Dato inicial
w0=np.ones((n,))/n
# Cotas de las variables
bnds=((0,1),)*n
# Restricciones
cons={'type':'eq','fun':lambda w:w.sum()-1}

# %%
# Portafolio de mínima varianza
minvar=minimize(fun=varianza,
               x0=w0,
               args=(Sigma,),
               bounds=bnds,
               constraints=cons,
               tol=1e-10)
minvar
# Out:
#      fun: 0.017420006898292477
#      jac: array([0.03800932, 0.0435786 , 0.03822194, 0.03876755, 0.03484001,
#        0.03484042, 0.05084545, 0.03525463, 0.03483974, 0.04343543,
#        0.03483978, 0.04961288, 0.03483967, 0.03906494, 0.03484002])
#  message: 'Optimization terminated successfully.'
#     nfev: 578
#      nit: 34
#     njev: 34
#   status: 0
#  success: True
#        x: array([7.17323855e-18, 0.00000000e+00, 4.81253788e-17, 0.00000000e+00,
#        4.62588564e-01, 7.18462128e-02, 2.64329795e-18, 0.00000000e+00,
#        7.40514581e-02, 5.43196875e-18, 1.93743896e-02, 9.79452167e-18,
#        4.67705429e-03, 0.00000000e+00, 3.67462321e-01])

# %%
w_minvar=minvar.x
w_minvar
# Out:
# array([7.17323855e-18, 0.00000000e+00, 4.81253788e-17, 0.00000000e+00,
#        4.62588564e-01, 7.18462128e-02, 2.64329795e-18, 0.00000000e+00,
#        7.40514581e-02, 5.43196875e-18, 1.93743896e-02, 9.79452167e-18,
#        4.67705429e-03, 0.00000000e+00, 3.67462321e-01])

# %%
rf=.0308
E_minvar=Eind.T.dot(w_minvar)
s_minvar=(w_minvar.T.dot(Sigma).dot(w_minvar))**.5
RS_minvar=(E_minvar-rf)/s_minvar
E_minvar,s_minvar,RS_minvar
# Out:
# (0.123231830545611, 0.1319848737480643, 0.7003213922986883)

# %%
# Portafolio EMV
EMV=minimize(fun=menos_RS,
            x0=w0,
            args=(Eind,Sigma,rf),
            bounds=bnds,
            constraints=cons,
            tol=1e-8)
EMV
# Out:
#      fun: -1.410952459951984
#      jac: array([-0.03884344,  0.20247032,  0.07033187,  0.08730431, -0.04203188,
#         0.2709287 , -0.12236044, -0.00793041, -0.12236756,  0.55004904,
#        -0.12237616,  0.24928533, -0.12235677, -0.12234725, -0.12236324])
#  message: 'Optimization terminated successfully.'
#     nfev: 222
#      nit: 13
#     njev: 13
#   status: 0
#  success: True
#        x: array([8.87433214e-17, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.13389559e-17, 4.99261647e-18, 2.03286661e-01, 0.00000000e+00,
#        4.97200102e-02, 2.89355188e-16, 3.08430666e-01, 0.00000000e+00,
#        2.19927388e-01, 1.80048436e-01, 3.85868395e-02])

# %%
w_EMV=EMV.x
w_EMV
# Out:
# array([8.87433214e-17, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.13389559e-17, 4.99261647e-18, 2.03286661e-01, 0.00000000e+00,
#        4.97200102e-02, 2.89355188e-16, 3.08430666e-01, 0.00000000e+00,
#        2.19927388e-01, 1.80048436e-01, 3.85868395e-02])

# %%
# Pesos, rendimiento y riesgo del portafolio EMV
E_EMV=Eind.T.dot(w_EMV)
s_EMV=(w_EMV.T.dot(Sigma).dot(w_EMV))**0.5
RS_EMV=(E_EMV-rf)/s_EMV
E_EMV,s_EMV,RS_EMV
# Out:
# (0.3859521831608758, 0.25171094933486415, 1.410952459951984)

# %%
# Covarianza entre los portafolios
cov=w_EMV.T.dot(Sigma).dot(w_minvar)
cov
# Out:
# 0.01942711713342119

# %%
# Correlación entre los portafolios
corr=cov/(s_EMV*s_minvar)
corr
# Out:
# 0.5847659680012576

# %%
frontera=pd.DataFrame(data={'w_EMV':w,
                           'w_minvar':1-w,
                           'Media':w*E_EMV+(1-w)*E_minvar,
                           'Vol':((w*s_EMV)**2+((1-w)*s_minvar)**2+2*w*(1-w)*cov)**0.5})
frontera['RS']=(frontera['Media']-rf)/frontera['Vol']
frontera
# Out:
#      w_EMV  w_minvar     Media       Vol        RS
# 0     0.00      1.00  0.123232  0.131985  0.700321
# 1     0.01      0.99  0.125859  0.132153  0.719312
# 2     0.02      0.98  0.128486  0.132352  0.738079
# 3     0.03      0.97  0.131113  0.132583  0.756610
# 4     0.04      0.96  0.133741  0.132844  0.774896
# ..     ...       ...       ...       ...       ...
# 96    0.96      0.04  0.375443  0.244767  1.408046
# 97    0.97      0.03  0.378071  0.246496  1.408829
# 98    0.98      0.02  0.380698  0.248230  1.409573
# 99    0.99      0.01  0.383325  0.249968  1.410281
# 100   1.00      0.00  0.385952  0.251711  1.410952
#
# [101 rows x 5 columns]

# %%
wp=np.linspace(0,1.5,N)
LAC=pd.DataFrame(data={'wp':wp,
                       'wf':1-wp,
                        'Media':wp*E_EMV+(1-wp)*rf,
                         'Vol':wp*s_EMV})
LAC['RS']=(LAC['Media']-rf)/LAC['Vol']
LAC
# Out:
#         wp     wf     Media       Vol        RS
# 0    0.000  1.000  0.030800  0.000000       NaN
# 1    0.015  0.985  0.036127  0.003776  1.410952
# 2    0.030  0.970  0.041455  0.007551  1.410952
# 3    0.045  0.955  0.046782  0.011327  1.410952
# 4    0.060  0.940  0.052109  0.015103  1.410952
# ..     ...    ...       ...       ...       ...
# 96   1.440 -0.440  0.542219  0.362464  1.410952
# 97   1.455 -0.455  0.547546  0.366239  1.410952
# 98   1.470 -0.470  0.552874  0.370015  1.410952
# 99   1.485 -0.485  0.558201  0.373791  1.410952
# 100  1.500 -0.500  0.563528  0.377566  1.410952
#
# [101 rows x 5 columns]

# %%
summary
# Out:
#             Media       Vol
# Symbols
# VNQ      0.155493  0.199559
# VBK      0.143562  0.205940
# SPY      0.130934  0.157928
# VTI      0.132863  0.162344
# VYM      0.132139  0.139865
# IBM      0.045872  0.190062
# AAL      0.493348  0.504898
# GOOG     0.181028  0.257254
# PFE      0.143711  0.187987
# SONY     0.025782  0.343752
# AAPL     0.254032  0.266587
# VWAGY    0.123264  0.351877
# NFLX     0.625627  0.591866
# AMZN     0.324013  0.328069
# KO       0.109726  0.152303

# %%
plt.scatter(frontera["Vol"],
frontera["Media"],
c=frontera["RS"],
cmap="RdYlBu",
label="Frontera de minima varianza")
# Activos ind
for i in range(n):
    plt.plot(summary.iloc[i, 1], summary.iloc[i, 0], "o", ms=11, label=summary.index[i])
# Port. óptimos
plt.plot(s_EMV, E_EMV, "dm", ms=10, label="Portafolio EMV")
plt.plot(s_minvar, E_minvar, "db", ms=10, label="Portafolio mínima varianza")
plt.plot(LAC["Vol"], LAC["Media"], "--", label="LAC")
# Etiquetas de los ejes
plt.xlabel("Volatilidad $\sigma$")
plt.ylabel("Rendimiento esperado $E[r]$")
# Leyenda
plt.legend(loc="upper left", bbox_to_anchor=(1.3, 1))
plt.plot(0,rf,'ok',ms=8,label='Libre de riesgo')
plt.grid()
#plt.axis([0.03, 0.06, 0.0, 0.015]);

# %%
#Asignación de capital
w_opt=(E_EMV-rf)/(g*s_EMV**2)
w_opt,1-w_opt
# Out:
# (0.7006809118158984, 0.2993190881841016)

# %%
summary
# Out:
#             Media       Vol
# Symbols
# VNQ      0.155493  0.199559
# VBK      0.143562  0.205940
# SPY      0.130934  0.157928
# VTI      0.132863  0.162344
# VYM      0.132139  0.139865
# IBM      0.045872  0.190062
# AAL      0.493348  0.504898
# GOOG     0.181028  0.257254
# PFE      0.143711  0.187987
# SONY     0.025782  0.343752
# AAPL     0.254032  0.266587
# VWAGY    0.123264  0.351877
# NFLX     0.625627  0.591866
# AMZN     0.324013  0.328069
# KO       0.109726  0.152303

# %%
VNQ=w_EMV[0]*w_opt
VBQ=w_EMV[1]*w_opt
SPY=w_EMV[2]*w_opt
VTI=w_EMV[3]*w_opt
VYM=w_EMV[4]*w_opt
IBM=w_EMV[5]*w_opt
AAL=w_EMV[6]*w_opt
GOOG=w_EMV[7]*w_opt
PFE=w_EMV[8]*w_opt
SONY=w_EMV[9]*w_opt
AAPL=w_EMV[10]*w_opt
VWAGY=w_EMV[11]*w_opt
NFLX=w_EMV[12]*w_opt
AMZN=w_EMV[13]*w_opt
KO=w_EMV[14]*w_opt
#Tasa libre de riesgo
por_rf=1-w_opt

# %%
a=[VNQ,VBQ,SPY,VTI,VYM,IBM,AAL,GOOG,PFE,SONY,AAPL,VWAGY,NFLX,AMZN,KO,por_rf]

a = [i*100 for i in a]

# %%
tickers_1 = 'VNQ VBK SPY VTI VYM IBM AAL GOOG PFE SONY AAPL VWAGY NFLX AMZN KO CETES'
tickers_1 = tickers_1.split(' ')

# %%
a_c = pd.DataFrame(columns=['Asignación de capital %'], index=[tickers_1])
a_c['Asignación de capital %']=a
# Out:
#        Asignación de capital %
# VNQ               6.218075e-15
# VBK               0.000000e+00
# SPY               0.000000e+00
# VTI               0.000000e+00
# VYM               7.944990e-16
# IBM               3.498231e-16
# AAL               1.424391e+01
# GOOG              0.000000e+00
# PFE               3.483786e+00
# SONY              2.027457e-14
# AAPL              2.161115e+01
# VWAGY             0.000000e+00
# NFLX              1.540989e+01
# AMZN              1.261565e+01
# KO                2.703706e+00
# CETES             2.993191e+01

# %% [markdown]
# # 2.2

# %% [markdown]
# # 2.3

# %% [markdown]
# # 2.4

# %% [markdown]
# # 2.5

# %% [markdown]
# # 2.6

# %% [markdown]
# ## 3. Evaluación del rendimiento
#
# Usando los portafolios que encontraron en el punto anterior, deberán encontrar:
#
# 1. El rendimiento del portafolio 2 durante el 2016.
#
# 2. El rendimiento del portafolio 3 durante el 2017.
#
# 3. El rendimiento del portafolio 4 durante el 2018.
#
# 4. El rendimiento del portafolio 5 durante el 2019.
#
# 5. El rendimiento del portafolio 6 durante el 2020.
#
# 6. El rendimiento del portafolio 6 durante lo que va del 2021.
#
# 6. El rendimiento total durante  el periodo de tenencia.
#
# 7. El rendimiento promedio anual durante el periodo de tenencia.
#
# 9. Si hubieran invertido 10.000 USD en estos portafolios a lo largo del tiempo y nunca hubieran retirado ni adicionado nada más, ¿Cuánto dinero tendrían invertido en este momento?

# %% [markdown]
# # 3.1

# %%
start = '2016-01-01'
end = '2016-12-31'
prices=get_adj_closes(tickers, start, end, 'd')
ret = prices.pct_change().dropna()
ret.head()
# Out:
# Symbols          VNQ       VBK       SPY       VTI       VYM       IBM  \
# Date
# 2016-01-05  0.019297  0.000419  0.001691  0.002239  0.005004 -0.000735
# 2016-01-06 -0.002740 -0.015596 -0.012614 -0.013402 -0.013126 -0.005006
# 2016-01-07 -0.019483 -0.028109 -0.023991 -0.024510 -0.021557 -0.017089
# 2016-01-08 -0.013374 -0.014636 -0.010977 -0.011403 -0.011250 -0.009258
# 2016-01-11  0.005681 -0.008272  0.000990 -0.000612  0.001106  0.012155
#
# Symbols          AAL      GOOG       PFE      SONY      AAPL     VWAGY  \
# Date
# 2016-01-05 -0.009533  0.000998  0.007199  0.029923 -0.025059 -0.058472
# 2016-01-06  0.017522  0.001400 -0.017713 -0.072242 -0.019570 -0.007057
# 2016-01-07 -0.018918 -0.023170 -0.006643 -0.015235 -0.042205 -0.045842
# 2016-01-08 -0.001978 -0.016410 -0.012739 -0.011603  0.005288  0.017058
# 2016-01-11  0.017587  0.002184  0.002258  0.015652  0.016193  0.019848
#
# Symbols         NFLX      AMZN        KO
# Date
# 2016-01-05 -0.020917 -0.005024  0.003537
# 2016-01-06  0.093071 -0.001799 -0.005405
# 2016-01-07 -0.026513 -0.039058 -0.016541
# 2016-01-08 -0.027671 -0.001464 -0.002643
# 2016-01-11  0.032139  0.017610  0.001686

# %%
t=ret.mean()*252
t.sum()*100
# Out:
# 208.57489049445212

# %% [markdown]
# ## 4. Adicional
#
# Todo lo anterior es lo mínimo necesario del proyecto. Sin embargo, se considerarán ampliamente si ustedes miden el comportamiento de los portafolios con otras métricas que se les ocurran.
#
# Además, se considerará ampliamente también si tienen en cuenta los precios reales de los activos en el momento de la compra, y como modifica esto las ponderaciones que encontraron para sus portafolios, considerando que no pueden comprar fracciones de activos y/o ETFs.

# %% [markdown]
# ## 5. Presentación
#
# Todo lo anterior lo deben realizar en un notebook de jupyter considerando que de ahí mismo realizarán la presentación del proyecto.

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Esteban Jiménez Rodríguez.
# </footer>
